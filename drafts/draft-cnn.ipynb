# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
DATASET_PATH = "/kaggle/input/datasets/alessiocorrado99/animals10/raw-img"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
train_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 20947 images belonging to 10 classes.

# %%
val_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 5232 images belonging to 10 classes.

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(train_gen.num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5
)
# Out:
# Epoch 1/5
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 212s 323ms/step - accuracy: 0.3473 - loss: 2.0236 - val_accuracy: 0.5545 - val_loss: 1.3303
# Epoch 2/5
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 70s 107ms/step - accuracy: 0.6026 - loss: 1.1779 - val_accuracy: 0.5845 - val_loss: 1.2195
# Epoch 3/5
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 67s 103ms/step - accuracy: 0.7603 - loss: 0.7226 - val_accuracy: 0.5973 - val_loss: 1.2770
# Epoch 4/5
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 68s 103ms/step - accuracy: 0.8741 - loss: 0.3948 - val_accuracy: 0.5856 - val_loss: 1.5560
# Epoch 5/5
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 68s 104ms/step - accuracy: 0.9249 - loss: 0.2347 - val_accuracy: 0.5881 - val_loss: 1.7163
